# %% [markdown]
# Importing libraries and data files

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import LabelEncoder


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
import warnings 
warnings.filterwarnings('ignore')
pd.set_option('max_columns', 20)
# Out:
# /kaggle/input/janatahack-crosssell-prediction/sample_submission.csv
# /kaggle/input/janatahack-crosssell-prediction/test.csv
# /kaggle/input/janatahack-crosssell-prediction/train.csv

# %%
train = pd.read_csv('/kaggle/input/janatahack-crosssell-prediction/train.csv',index_col=0)
test = pd.read_csv('/kaggle/input/janatahack-crosssell-prediction/test.csv',index_col=0)
sample_submission = pd.read_csv('/kaggle/input/janatahack-crosssell-prediction/sample_submission.csv',index_col=0)

# %%
train[['Driving_License','Previously_Insured','Policy_Sales_Channel']] = train[['Driving_License','Previously_Insured','Policy_Sales_Channel']].astype('object')
train['Response'] = train['Response'].astype('object')

test[['Driving_License','Previously_Insured','Policy_Sales_Channel']] = test[['Driving_License','Previously_Insured','Policy_Sales_Channel']].astype('object')

# %% [markdown]
# Data pre-processing

# %%
X = train.drop('Response',axis=1)
y = train['Response'].values

# %%
X = pd.get_dummies(X,drop_first=True)
test = pd.get_dummies(test,drop_first=True)

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %% [markdown]
# Training the model

# %%
clf = LGBMClassifier(n_estimators=550,
                     learning_rate=0.03,
                     min_child_samples=40,
                     random_state=1,
                     colsample_bytree=0.5,
                     reg_alpha=2,
                     reg_lambda=2)

clf.fit(X, y, verbose=50,eval_metric = 'auc')
# Out:
# LGBMClassifier(colsample_bytree=0.5, learning_rate=0.03, min_child_samples=40,
#                n_estimators=550, random_state=1, reg_alpha=2, reg_lambda=2)

# %%
lgb_pred = clf.predict_proba(X)[:,1]
roc_auc_score(y,lgb_pred)
# Out:
# 0.8648823717319468

# %% [markdown]
# Pre-processing test data and predicting probabilities

# %%
missing_cols
# Out:
# {'Policy_Sales_Channel_104.0',
#  'Policy_Sales_Channel_143.0',
#  'Policy_Sales_Channel_144.0',
#  'Policy_Sales_Channel_149.0',
#  'Policy_Sales_Channel_27.0',
#  'Policy_Sales_Channel_28.0',
#  'Policy_Sales_Channel_41.0',
#  'Policy_Sales_Channel_50.0',
#  'Policy_Sales_Channel_67.0',
#  'Policy_Sales_Channel_68.0',
#  'Policy_Sales_Channel_75.0',
#  'Policy_Sales_Channel_84.0'}

# %%
print(test.shape,X.shape)

missing_cols = set(X.columns) - set(test.columns)
for c in missing_cols:
    test[c] = 0

print(test.shape,X.shape)

#keeping the order of columns same for X and test
test = test[X.columns]
# Out:
# (127037, 154) (381109, 164)
# (127037, 166) (381109, 164)

# %%
test_pred = clf.predict_proba(test)[:,1]

# %%
sample_submission['Response'] = test_pred
sample_submission.to_csv('Submission_v1.csv')

# %% [markdown]
# Hyperparameter tuning

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2020, stratify=y)

# %%
#Preparing learning rate shrinkage
def learning_rate_010_decay_power_099(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_010_decay_power_0995(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.995, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_005_decay_power_099(current_iter):
    base_learning_rate = 0.05
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

# %%
#Using test subset for early stopping
import lightgbm as lgb
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [(X_test,y_test)],
            'eval_names': ['valid'],
            #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_099)],
            'verbose': 100,
            'categorical_feature': 'auto'}

# %%
#Setup hyperparameter search
from scipy.stats import uniform as sp_uniform
from scipy.stats import randint as sp_randint
param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

# %%
#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

# %%
gs.fit(X_train, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857045
# Early stopping, best iteration is:
# [97]	valid's auc: 0.857101
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857103
# Early stopping, best iteration is:
# [103]	valid's auc: 0.857104
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856945
# Early stopping, best iteration is:
# [133]	valid's auc: 0.857077
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856571
# Early stopping, best iteration is:
# [135]	valid's auc: 0.856633
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856815
# Early stopping, best iteration is:
# [85]	valid's auc: 0.856887
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856703
# Early stopping, best iteration is:
# [106]	valid's auc: 0.856746
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [4]	valid's auc: 0.808977
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [4]	valid's auc: 0.80889
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.806519
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853175
# [200]	valid's auc: 0.853644
# Early stopping, best iteration is:
# [219]	valid's auc: 0.853695
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85284
# [200]	valid's auc: 0.853267
# Early stopping, best iteration is:
# [198]	valid's auc: 0.853289
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853104
# Early stopping, best iteration is:
# [141]	valid's auc: 0.853318
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854641
# Early stopping, best iteration is:
# [139]	valid's auc: 0.85468
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854803
# Early stopping, best iteration is:
# [126]	valid's auc: 0.854833
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854714
# Early stopping, best iteration is:
# [106]	valid's auc: 0.854731
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856683
# Early stopping, best iteration is:
# [151]	valid's auc: 0.857245
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856786
# [200]	valid's auc: 0.857532
# Early stopping, best iteration is:
# [247]	valid's auc: 0.85771
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857141
# Early stopping, best iteration is:
# [165]	valid's auc: 0.857706
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [69]	valid's auc: 0.856676
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [59]	valid's auc: 0.856594
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [59]	valid's auc: 0.856801
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856784
# Early stopping, best iteration is:
# [123]	valid's auc: 0.856843
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856513
# Early stopping, best iteration is:
# [156]	valid's auc: 0.856669
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856359
# Early stopping, best iteration is:
# [73]	valid's auc: 0.856536
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85709
# [200]	valid's auc: 0.857757
# Early stopping, best iteration is:
# [193]	valid's auc: 0.857769
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857104
# [200]	valid's auc: 0.857486
# Early stopping, best iteration is:
# [228]	valid's auc: 0.857572
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857053
# [200]	valid's auc: 0.857546
# Early stopping, best iteration is:
# [217]	valid's auc: 0.857591
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857246
# [200]	valid's auc: 0.857263
# Early stopping, best iteration is:
# [173]	valid's auc: 0.857433
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857683
# Early stopping, best iteration is:
# [130]	valid's auc: 0.857917
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85757
# Early stopping, best iteration is:
# [114]	valid's auc: 0.857698
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856422
# Early stopping, best iteration is:
# [84]	valid's auc: 0.856483
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857033
# Early stopping, best iteration is:
# [113]	valid's auc: 0.857159
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856576
# Early stopping, best iteration is:
# [94]	valid's auc: 0.856602
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [56]	valid's auc: 0.856297
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856719
# Early stopping, best iteration is:
# [76]	valid's auc: 0.856754
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856915
# Early stopping, best iteration is:
# [93]	valid's auc: 0.856954
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856513
# Early stopping, best iteration is:
# [102]	valid's auc: 0.856541
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857071
# Early stopping, best iteration is:
# [138]	valid's auc: 0.857219
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856978
# Early stopping, best iteration is:
# [106]	valid's auc: 0.857006
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852614
# [200]	valid's auc: 0.853209
# [300]	valid's auc: 0.853414
# Early stopping, best iteration is:
# [299]	valid's auc: 0.853429
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852375
# [200]	valid's auc: 0.853098
# [300]	valid's auc: 0.853287
# [400]	valid's auc: 0.853381
# Early stopping, best iteration is:
# [410]	valid's auc: 0.85341
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852237
# [200]	valid's auc: 0.852842
# Early stopping, best iteration is:
# [232]	valid's auc: 0.852942
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856632
# Early stopping, best iteration is:
# [137]	valid's auc: 0.856707
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856824
# Early stopping, best iteration is:
# [117]	valid's auc: 0.856962
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856614
# Early stopping, best iteration is:
# [78]	valid's auc: 0.856666
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855911
# [200]	valid's auc: 0.856487
# [300]	valid's auc: 0.856682
# Early stopping, best iteration is:
# [290]	valid's auc: 0.856721
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856005
# [200]	valid's auc: 0.856769
# Early stopping, best iteration is:
# [214]	valid's auc: 0.856791
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856345
# [200]	valid's auc: 0.856639
# Early stopping, best iteration is:
# [248]	valid's auc: 0.856724
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857066
# Early stopping, best iteration is:
# [159]	valid's auc: 0.857429
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857418
# [200]	valid's auc: 0.857731
# Early stopping, best iteration is:
# [218]	valid's auc: 0.857809
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857339
# Early stopping, best iteration is:
# [119]	valid's auc: 0.857399
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855354
# Early stopping, best iteration is:
# [166]	valid's auc: 0.855607
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855609
# Early stopping, best iteration is:
# [145]	valid's auc: 0.855807
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855468
# Early stopping, best iteration is:
# [153]	valid's auc: 0.855626
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857489
# Early stopping, best iteration is:
# [81]	valid's auc: 0.85763
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [40]	valid's auc: 0.857287
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857501
# Early stopping, best iteration is:
# [97]	valid's auc: 0.857509
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854242
# [200]	valid's auc: 0.854292
# Early stopping, best iteration is:
# [171]	valid's auc: 0.854292
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854536
# [200]	valid's auc: 0.854667
# Early stopping, best iteration is:
# [174]	valid's auc: 0.854667
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854621
# Early stopping, best iteration is:
# [122]	valid's auc: 0.854763
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856426
# [200]	valid's auc: 0.856927
# Early stopping, best iteration is:
# [203]	valid's auc: 0.856974
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856365
# [200]	valid's auc: 0.856943
# Early stopping, best iteration is:
# [207]	valid's auc: 0.856975
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856544
# [200]	valid's auc: 0.856985
# Early stopping, best iteration is:
# [175]	valid's auc: 0.857057
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854323
# Early stopping, best iteration is:
# [165]	valid's auc: 0.854368
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854707
# Early stopping, best iteration is:
# [122]	valid's auc: 0.854865
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854792
# Early stopping, best iteration is:
# [102]	valid's auc: 0.854809
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856334
# [200]	valid's auc: 0.856846
# Early stopping, best iteration is:
# [263]	valid's auc: 0.85707
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856445
# [200]	valid's auc: 0.857205
# [300]	valid's auc: 0.857498
# Early stopping, best iteration is:
# [310]	valid's auc: 0.85754
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856515
# [200]	valid's auc: 0.857239
# [300]	valid's auc: 0.857319
# Early stopping, best iteration is:
# [274]	valid's auc: 0.857408
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857161
# Early stopping, best iteration is:
# [79]	valid's auc: 0.857284
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856929
# Early stopping, best iteration is:
# [92]	valid's auc: 0.856978
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856947
# Early stopping, best iteration is:
# [84]	valid's auc: 0.857076
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.808577
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [4]	valid's auc: 0.80889
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.79039
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857405
# Early stopping, best iteration is:
# [150]	valid's auc: 0.857489
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857528
# Early stopping, best iteration is:
# [115]	valid's auc: 0.857606
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857488
# Early stopping, best iteration is:
# [119]	valid's auc: 0.857538
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857105
# Early stopping, best iteration is:
# [102]	valid's auc: 0.857111
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857202
# Early stopping, best iteration is:
# [99]	valid's auc: 0.85721
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857352
# Early stopping, best iteration is:
# [77]	valid's auc: 0.857444
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85577
# [200]	valid's auc: 0.856464
# [300]	valid's auc: 0.85669
# [400]	valid's auc: 0.856748
# Early stopping, best iteration is:
# [393]	valid's auc: 0.856776
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855895
# [200]	valid's auc: 0.856576
# [300]	valid's auc: 0.856848
# Early stopping, best iteration is:
# [340]	valid's auc: 0.856916
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856125
# [200]	valid's auc: 0.856628
# Early stopping, best iteration is:
# [188]	valid's auc: 0.856649
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855654
# [200]	valid's auc: 0.855898
# Early stopping, best iteration is:
# [190]	valid's auc: 0.855899
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85546
# [200]	valid's auc: 0.855889
# Early stopping, best iteration is:
# [177]	valid's auc: 0.855889
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855795
# Early stopping, best iteration is:
# [155]	valid's auc: 0.855978
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854697
# Early stopping, best iteration is:
# [104]	valid's auc: 0.854713
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85486
# Early stopping, best iteration is:
# [99]	valid's auc: 0.85486
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854874
# Early stopping, best iteration is:
# [155]	valid's auc: 0.854875
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856778
# Early stopping, best iteration is:
# [103]	valid's auc: 0.856823
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857207
# Early stopping, best iteration is:
# [116]	valid's auc: 0.857281
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856832
# Early stopping, best iteration is:
# [74]	valid's auc: 0.856933
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857225
# Early stopping, best iteration is:
# [105]	valid's auc: 0.857276
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857067
# Early stopping, best iteration is:
# [115]	valid's auc: 0.857191
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857218
# Early stopping, best iteration is:
# [77]	valid's auc: 0.857285
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855323
# Early stopping, best iteration is:
# [151]	valid's auc: 0.855622
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855568
# Early stopping, best iteration is:
# [153]	valid's auc: 0.855779
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855639
# Early stopping, best iteration is:
# [147]	valid's auc: 0.855809
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856624
# Early stopping, best iteration is:
# [95]	valid's auc: 0.85663
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856813
# Early stopping, best iteration is:
# [73]	valid's auc: 0.856903
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856741
# Early stopping, best iteration is:
# [83]	valid's auc: 0.856836
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857408
# [200]	valid's auc: 0.857504
# Early stopping, best iteration is:
# [173]	valid's auc: 0.85762
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857558
# [200]	valid's auc: 0.85793
# Early stopping, best iteration is:
# [200]	valid's auc: 0.85793
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857598
# Early stopping, best iteration is:
# [133]	valid's auc: 0.857719
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [6]	valid's auc: 0.808206
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.808577
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.79039
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853453
# [200]	valid's auc: 0.853806
# [300]	valid's auc: 0.853928
# Early stopping, best iteration is:
# [298]	valid's auc: 0.853938
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853123
# [200]	valid's auc: 0.853543
# Early stopping, best iteration is:
# [231]	valid's auc: 0.853604
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853235
# [200]	valid's auc: 0.853579
# Early stopping, best iteration is:
# [203]	valid's auc: 0.853614
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856599
# Early stopping, best iteration is:
# [131]	valid's auc: 0.856687
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857069
# Early stopping, best iteration is:
# [134]	valid's auc: 0.857169
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856324
# Early stopping, best iteration is:
# [120]	valid's auc: 0.856381
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856573
# Early stopping, best iteration is:
# [89]	valid's auc: 0.856655
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856698
# Early stopping, best iteration is:
# [86]	valid's auc: 0.85676
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [68]	valid's auc: 0.856812
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854608
# Early stopping, best iteration is:
# [142]	valid's auc: 0.854651
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85467
# [200]	valid's auc: 0.854828
# Early stopping, best iteration is:
# [172]	valid's auc: 0.854828
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.854666
# Early stopping, best iteration is:
# [153]	valid's auc: 0.854735
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [68]	valid's auc: 0.857293
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857002
# Early stopping, best iteration is:
# [75]	valid's auc: 0.857146
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856963
# Early stopping, best iteration is:
# [77]	valid's auc: 0.857102
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856816
# Early stopping, best iteration is:
# [166]	valid's auc: 0.857092
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85629
# [200]	valid's auc: 0.856916
# Early stopping, best iteration is:
# [221]	valid's auc: 0.857007
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856525
# Early stopping, best iteration is:
# [147]	valid's auc: 0.856668
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853125
# [200]	valid's auc: 0.853694
# Early stopping, best iteration is:
# [238]	valid's auc: 0.853727
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85287
# [200]	valid's auc: 0.853219
# [300]	valid's auc: 0.853376
# Early stopping, best iteration is:
# [292]	valid's auc: 0.853402
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853055
# [200]	valid's auc: 0.85329
# Early stopping, best iteration is:
# [193]	valid's auc: 0.8533
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852479
# [200]	valid's auc: 0.853038
# [300]	valid's auc: 0.853227
# Early stopping, best iteration is:
# [365]	valid's auc: 0.853316
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.8521
# [200]	valid's auc: 0.852789
# [300]	valid's auc: 0.852973
# Early stopping, best iteration is:
# [270]	valid's auc: 0.852995
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85249
# [200]	valid's auc: 0.852952
# Early stopping, best iteration is:
# [245]	valid's auc: 0.85305
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855213
# Early stopping, best iteration is:
# [150]	valid's auc: 0.855618
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855605
# Early stopping, best iteration is:
# [153]	valid's auc: 0.855871
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855499
# Early stopping, best iteration is:
# [156]	valid's auc: 0.855685
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856399
# Early stopping, best iteration is:
# [79]	valid's auc: 0.856536
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [57]	valid's auc: 0.856557
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856513
# Early stopping, best iteration is:
# [73]	valid's auc: 0.856782
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.806519
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.806519
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.806519
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852832
# [200]	valid's auc: 0.853428
# [300]	valid's auc: 0.853644
# [400]	valid's auc: 0.853728
# Early stopping, best iteration is:
# [417]	valid's auc: 0.853764
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852585
# [200]	valid's auc: 0.853094
# [300]	valid's auc: 0.853332
# Early stopping, best iteration is:
# [293]	valid's auc: 0.853367
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852667
# [200]	valid's auc: 0.853152
# Early stopping, best iteration is:
# [172]	valid's auc: 0.853187
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856644
# Early stopping, best iteration is:
# [102]	valid's auc: 0.856676
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856806
# Early stopping, best iteration is:
# [98]	valid's auc: 0.856828
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856599
# Early stopping, best iteration is:
# [102]	valid's auc: 0.856619
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855372
# [200]	valid's auc: 0.855474
# Early stopping, best iteration is:
# [202]	valid's auc: 0.855474
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855597
# Early stopping, best iteration is:
# [130]	valid's auc: 0.85575
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855735
# Early stopping, best iteration is:
# [135]	valid's auc: 0.85583
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856423
# Early stopping, best iteration is:
# [78]	valid's auc: 0.856551
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856647
# Early stopping, best iteration is:
# [106]	valid's auc: 0.856697
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856422
# Early stopping, best iteration is:
# [80]	valid's auc: 0.856544
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852773
# [200]	valid's auc: 0.853362
# [300]	valid's auc: 0.853649
# Early stopping, best iteration is:
# [315]	valid's auc: 0.853663
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853216
# [200]	valid's auc: 0.853592
# [300]	valid's auc: 0.853761
# Early stopping, best iteration is:
# [312]	valid's auc: 0.853791
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85271
# [200]	valid's auc: 0.853111
# [300]	valid's auc: 0.853242
# Early stopping, best iteration is:
# [353]	valid's auc: 0.853327
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.808577
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.806519
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.79039
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855735
# Early stopping, best iteration is:
# [120]	valid's auc: 0.855774
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855986
# Early stopping, best iteration is:
# [120]	valid's auc: 0.856086
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855812
# Early stopping, best iteration is:
# [124]	valid's auc: 0.855866
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85617
# [200]	valid's auc: 0.856791
# [300]	valid's auc: 0.856895
# Early stopping, best iteration is:
# [273]	valid's auc: 0.856915
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856167
# [200]	valid's auc: 0.856955
# [300]	valid's auc: 0.857216
# Early stopping, best iteration is:
# [344]	valid's auc: 0.857362
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856213
# [200]	valid's auc: 0.856854
# Early stopping, best iteration is:
# [198]	valid's auc: 0.856863
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856814
# Early stopping, best iteration is:
# [93]	valid's auc: 0.856841
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857038
# Early stopping, best iteration is:
# [168]	valid's auc: 0.857226
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856983
# Early stopping, best iteration is:
# [108]	valid's auc: 0.857021
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856354
# [200]	valid's auc: 0.85663
# Early stopping, best iteration is:
# [170]	valid's auc: 0.856717
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856717
# Early stopping, best iteration is:
# [151]	valid's auc: 0.856971
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85658
# Early stopping, best iteration is:
# [151]	valid's auc: 0.856787
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [67]	valid's auc: 0.856687
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [64]	valid's auc: 0.856911
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856152
# Early stopping, best iteration is:
# [79]	valid's auc: 0.856443
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856291
# Early stopping, best iteration is:
# [155]	valid's auc: 0.856577
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856849
# [200]	valid's auc: 0.857172
# Early stopping, best iteration is:
# [205]	valid's auc: 0.857186
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856532
# Early stopping, best iteration is:
# [140]	valid's auc: 0.856702
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [61]	valid's auc: 0.856645
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [57]	valid's auc: 0.85653
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [57]	valid's auc: 0.856394
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856543
# [200]	valid's auc: 0.857045
# [300]	valid's auc: 0.857079
# Early stopping, best iteration is:
# [290]	valid's auc: 0.857122
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856604
# [200]	valid's auc: 0.857372
# Early stopping, best iteration is:
# [198]	valid's auc: 0.857401
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856536
# [200]	valid's auc: 0.856874
# Early stopping, best iteration is:
# [254]	valid's auc: 0.857092
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85549
# [200]	valid's auc: 0.856388
# [300]	valid's auc: 0.856654
# Early stopping, best iteration is:
# [333]	valid's auc: 0.856749
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855461
# [200]	valid's auc: 0.856636
# [300]	valid's auc: 0.85695
# [400]	valid's auc: 0.857165
# Early stopping, best iteration is:
# [396]	valid's auc: 0.857185
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856025
# [200]	valid's auc: 0.856711
# Early stopping, best iteration is:
# [196]	valid's auc: 0.856758
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857243
# Early stopping, best iteration is:
# [93]	valid's auc: 0.857261
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857049
# Early stopping, best iteration is:
# [77]	valid's auc: 0.857164
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857322
# Early stopping, best iteration is:
# [99]	valid's auc: 0.857342
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855609
# Early stopping, best iteration is:
# [122]	valid's auc: 0.855625
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856052
# Early stopping, best iteration is:
# [124]	valid's auc: 0.85608
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855932
# [200]	valid's auc: 0.855985
# Early stopping, best iteration is:
# [172]	valid's auc: 0.855985
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856401
# [200]	valid's auc: 0.856773
# Early stopping, best iteration is:
# [196]	valid's auc: 0.856798
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856294
# [200]	valid's auc: 0.856782
# Early stopping, best iteration is:
# [209]	valid's auc: 0.856809
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856379
# [200]	valid's auc: 0.856687
# Early stopping, best iteration is:
# [208]	valid's auc: 0.856725
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856763
# Early stopping, best iteration is:
# [137]	valid's auc: 0.85689
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857012
# Early stopping, best iteration is:
# [143]	valid's auc: 0.857229
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856756
# Early stopping, best iteration is:
# [109]	valid's auc: 0.856804
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855416
# [200]	valid's auc: 0.856368
# [300]	valid's auc: 0.856855
# [400]	valid's auc: 0.857003
# [500]	valid's auc: 0.857155
# Early stopping, best iteration is:
# [525]	valid's auc: 0.857184
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855636
# [200]	valid's auc: 0.856667
# [300]	valid's auc: 0.857085
# [400]	valid's auc: 0.857256
# Early stopping, best iteration is:
# [465]	valid's auc: 0.857399
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855759
# [200]	valid's auc: 0.856806
# [300]	valid's auc: 0.857128
# Early stopping, best iteration is:
# [335]	valid's auc: 0.857177
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855195
# [200]	valid's auc: 0.856223
# [300]	valid's auc: 0.856618
# [400]	valid's auc: 0.856999
# Early stopping, best iteration is:
# [419]	valid's auc: 0.857022
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855534
# [200]	valid's auc: 0.856531
# [300]	valid's auc: 0.856995
# [400]	valid's auc: 0.857197
# Early stopping, best iteration is:
# [404]	valid's auc: 0.857212
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855137
# [200]	valid's auc: 0.856256
# [300]	valid's auc: 0.856709
# Early stopping, best iteration is:
# [360]	valid's auc: 0.856798
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855803
# Early stopping, best iteration is:
# [166]	valid's auc: 0.855917
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855731
# Early stopping, best iteration is:
# [130]	valid's auc: 0.855961
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855794
# Early stopping, best iteration is:
# [139]	valid's auc: 0.855973
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.806519
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.808577
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [3]	valid's auc: 0.79039
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853096
# [200]	valid's auc: 0.853653
# [300]	valid's auc: 0.853796
# Early stopping, best iteration is:
# [281]	valid's auc: 0.853808
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852899
# [200]	valid's auc: 0.853366
# Early stopping, best iteration is:
# [261]	valid's auc: 0.853523
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853116
# [200]	valid's auc: 0.853412
# Early stopping, best iteration is:
# [207]	valid's auc: 0.853433
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855349
# [200]	valid's auc: 0.855454
# Early stopping, best iteration is:
# [185]	valid's auc: 0.855455
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855456
# Early stopping, best iteration is:
# [151]	valid's auc: 0.855653
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855414
# Early stopping, best iteration is:
# [130]	valid's auc: 0.855527
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857132
# [200]	valid's auc: 0.85758
# Early stopping, best iteration is:
# [230]	valid's auc: 0.857688
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857258
# [200]	valid's auc: 0.857676
# Early stopping, best iteration is:
# [201]	valid's auc: 0.85769
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857468
# Early stopping, best iteration is:
# [135]	valid's auc: 0.857657
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852822
# [200]	valid's auc: 0.853326
# Early stopping, best iteration is:
# [254]	valid's auc: 0.853422
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852709
# [200]	valid's auc: 0.853211
# [300]	valid's auc: 0.853406
# Early stopping, best iteration is:
# [324]	valid's auc: 0.85345
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853011
# [200]	valid's auc: 0.853337
# [300]	valid's auc: 0.853396
# Early stopping, best iteration is:
# [291]	valid's auc: 0.853425
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855277
# [200]	valid's auc: 0.855513
# [300]	valid's auc: 0.855516
# [400]	valid's auc: 0.855516
# [500]	valid's auc: 0.855516
# Early stopping, best iteration is:
# [471]	valid's auc: 0.855516
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855398
# Early stopping, best iteration is:
# [151]	valid's auc: 0.855731
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855543
# Early stopping, best iteration is:
# [163]	valid's auc: 0.855758
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856658
# Early stopping, best iteration is:
# [109]	valid's auc: 0.856687
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856753
# Early stopping, best iteration is:
# [91]	valid's auc: 0.856784
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856672
# Early stopping, best iteration is:
# [94]	valid's auc: 0.85671
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856956
# Early stopping, best iteration is:
# [133]	valid's auc: 0.857014
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856769
# Early stopping, best iteration is:
# [106]	valid's auc: 0.856828
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [68]	valid's auc: 0.85671
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855789
# [200]	valid's auc: 0.855888
# Early stopping, best iteration is:
# [185]	valid's auc: 0.855888
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855731
# Early stopping, best iteration is:
# [127]	valid's auc: 0.855847
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855932
# Early stopping, best iteration is:
# [146]	valid's auc: 0.85604
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853257
# [200]	valid's auc: 0.853683
# [300]	valid's auc: 0.853748
# Early stopping, best iteration is:
# [292]	valid's auc: 0.853755
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.852898
# [200]	valid's auc: 0.853339
# [300]	valid's auc: 0.85342
# Early stopping, best iteration is:
# [330]	valid's auc: 0.853446
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.853248
# [200]	valid's auc: 0.853406
# Early stopping, best iteration is:
# [201]	valid's auc: 0.853414
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856473
# Early stopping, best iteration is:
# [85]	valid's auc: 0.856579
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856791
# Early stopping, best iteration is:
# [94]	valid's auc: 0.856841
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856624
# Early stopping, best iteration is:
# [95]	valid's auc: 0.856684
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [67]	valid's auc: 0.856164
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [61]	valid's auc: 0.856247
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [62]	valid's auc: 0.856297
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855311
# [200]	valid's auc: 0.855463
# Early stopping, best iteration is:
# [232]	valid's auc: 0.855463
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855762
# Early stopping, best iteration is:
# [126]	valid's auc: 0.855823
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.8555
# Early stopping, best iteration is:
# [134]	valid's auc: 0.85563
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856488
# [200]	valid's auc: 0.856962
# Early stopping, best iteration is:
# [221]	valid's auc: 0.857005
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856588
# [200]	valid's auc: 0.857196
# Early stopping, best iteration is:
# [221]	valid's auc: 0.857241
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856584
# Early stopping, best iteration is:
# [167]	valid's auc: 0.857015
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856905
# Early stopping, best iteration is:
# [92]	valid's auc: 0.856992
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85717
# Early stopping, best iteration is:
# [91]	valid's auc: 0.85725
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857183
# Early stopping, best iteration is:
# [99]	valid's auc: 0.85719
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857171
# Early stopping, best iteration is:
# [113]	valid's auc: 0.857339
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857531
# Early stopping, best iteration is:
# [150]	valid's auc: 0.857728
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857412
# Early stopping, best iteration is:
# [100]	valid's auc: 0.857412
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85617
# Early stopping, best iteration is:
# [90]	valid's auc: 0.856199
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856086
# Early stopping, best iteration is:
# [77]	valid's auc: 0.856216
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856272
# Early stopping, best iteration is:
# [89]	valid's auc: 0.856312
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856993
# Early stopping, best iteration is:
# [152]	valid's auc: 0.857242
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857239
# Early stopping, best iteration is:
# [144]	valid's auc: 0.857329
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857209
# Early stopping, best iteration is:
# [114]	valid's auc: 0.857281
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856544
# Early stopping, best iteration is:
# [128]	valid's auc: 0.856584
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856643
# Early stopping, best iteration is:
# [74]	valid's auc: 0.856685
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856433
# Early stopping, best iteration is:
# [77]	valid's auc: 0.856615
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857268
# [200]	valid's auc: 0.857597
# Early stopping, best iteration is:
# [178]	valid's auc: 0.857632
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857141
# [200]	valid's auc: 0.857369
# Early stopping, best iteration is:
# [171]	valid's auc: 0.857462
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857342
# Early stopping, best iteration is:
# [146]	valid's auc: 0.857442
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856798
# [200]	valid's auc: 0.857177
# Early stopping, best iteration is:
# [180]	valid's auc: 0.857209
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856723
# [200]	valid's auc: 0.857034
# Early stopping, best iteration is:
# [237]	valid's auc: 0.857092
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856869
# Early stopping, best iteration is:
# [131]	valid's auc: 0.856976
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856447
# Early stopping, best iteration is:
# [123]	valid's auc: 0.856619
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856632
# Early stopping, best iteration is:
# [134]	valid's auc: 0.856853
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856506
# Early stopping, best iteration is:
# [108]	valid's auc: 0.856603
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.855964
# [200]	valid's auc: 0.85643
# [300]	valid's auc: 0.856563
# Early stopping, best iteration is:
# [310]	valid's auc: 0.856601
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856381
# [200]	valid's auc: 0.857057
# [300]	valid's auc: 0.857195
# Early stopping, best iteration is:
# [305]	valid's auc: 0.857195
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85641
# [200]	valid's auc: 0.856829
# Early stopping, best iteration is:
# [216]	valid's auc: 0.856855
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793782
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857201
# Early stopping, best iteration is:
# [142]	valid's auc: 0.857349
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.85743
# Early stopping, best iteration is:
# [134]	valid's auc: 0.857615
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857453
# Early stopping, best iteration is:
# [96]	valid's auc: 0.857486
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856661
# [200]	valid's auc: 0.856942
# Early stopping, best iteration is:
# [178]	valid's auc: 0.857041
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856585
# Early stopping, best iteration is:
# [143]	valid's auc: 0.856905
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856705
# Early stopping, best iteration is:
# [149]	valid's auc: 0.85683
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856852
# Early stopping, best iteration is:
# [135]	valid's auc: 0.856988
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856885
# Early stopping, best iteration is:
# [109]	valid's auc: 0.85699
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856693
# Early stopping, best iteration is:
# [101]	valid's auc: 0.856715
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856425
# [200]	valid's auc: 0.856679
# Early stopping, best iteration is:
# [183]	valid's auc: 0.856692
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856819
# [200]	valid's auc: 0.857282
# Early stopping, best iteration is:
# [268]	valid's auc: 0.857338
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.856786
# [200]	valid's auc: 0.857104
# Early stopping, best iteration is:
# [195]	valid's auc: 0.857144
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed: 22.4min finished
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.857973
# Early stopping, best iteration is:
# [159]	valid's auc: 0.858295
# Best score reached: 0.8573948889237052 with params: {'colsample_bytree': 0.5284213741879101, 'min_child_samples': 125, 'min_child_weight': 10.0, 'num_leaves': 22, 'reg_alpha': 0.1, 'reg_lambda': 20, 'subsample': 0.3080033455431848}

# %%
opt_parameters = {'colsample_bytree': 0.5284213741879101, 'min_child_samples': 125, 'min_child_weight': 10.0, 'num_leaves': 22, 'reg_alpha': 0.1, 'reg_lambda': 20, 'subsample': 0.3080033455431848}

# %%
best_params = {'boosting_type': 'gbdt',
 'class_weight': None,
 'colsample_bytree': 0.5284213741879101,
 'importance_type': 'split',
 'learning_rate': 0.1,
 'max_depth': -1,
 'min_child_samples': 125,
 'min_child_weight': 10.0,
 'min_split_gain': 0.0,
 'n_estimators': 5000,
 'n_jobs': 4,
 'num_leaves': 22,
 'objective': None,
 'random_state': 314,
 'reg_alpha': 0.1,
 'reg_lambda': 20,
 'silent': True,
 'subsample': 0.3080033455431848,
 'subsample_for_bin': 200000,
 'subsample_freq': 0,
 'metric': 'None'}

# %%
clf_final = lgb.LGBMClassifier(**gs.best_estimator_.get_params())

# %%
clf_final.fit(X_train, y_train, **fit_params, callbacks=[lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_0995)])
# Out:
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.858007
# [200]	valid's auc: 0.85834
# [300]	valid's auc: 0.858407
# Early stopping, best iteration is:
# [336]	valid's auc: 0.858414
# LGBMClassifier(colsample_bytree=0.5284213741879101, metric='None',
#                min_child_samples=125, min_child_weight=10.0, n_estimators=5000,
#                n_jobs=4, num_leaves=22, random_state=314, reg_alpha=0.1,
#                reg_lambda=20, subsample=0.3080033455431848)

# %%
probabilities = clf_final.predict_proba(test)[:,1]
sample_submission['Response'] = probabilities
sample_submission.to_csv('Submission_v2.csv')
